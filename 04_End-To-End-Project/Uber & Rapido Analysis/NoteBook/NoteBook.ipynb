# %% [markdown]
# # **Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as tick
print('Libraries Loaded✅')
# Out:
# Libraries Loaded✅

# %% [markdown]
# # **Data Exploration & Understanding**

# %% [markdown]
# ## *Load the Data*

# %%
File_path = input("Enter The File Path: ").replace('\\','\\')
df = pd.read_csv(File_path)
print('Data Loaded Boss✅')
# Out:
# Data Loaded Boss✅

# %% [markdown]
# ## *Exploration*

# %%
print(f'The Data have {df.shape[0]} Rows and {df.shape[1]} Columns')
# Out:
# The Data have 50000 Rows and 33 Columns

# %%
df.head(20).T
# Out:
#                                                     0   \
# driver_id                                    DRV016649
# driver_name                             Naresh Chauhan
# age                                                NaN
# city                                           Chennai
# phone                                       9255500096
# email                       naresh.chauhan@hotmail.com
# platform                                          uber
# vehicle_type                                      auto
# vehicle_condition                                 good
# experience_level                                0-1 yr
# preferred_shift                                  NIGHT
# reason_for_joining                         Side hustle
# languages_known                   Hindi, Tamil, Telugu
# overall_driver_rating                              NaN
# total_trips_completed                           2752.0
# trip_completion_rate_%                            68.4
# cancellation_rate_%                               17.5
# avg_daily_earnings_INR                            2275
# total_complaints                                  36.0
# total_compliments                                 77.0
# peak_hour_availability                              No
# interview_date                            10 July 2023
# communication_score_10                            10.4
# driving_test_score_10                              4.3
# route_knowledge_score_10                           5.8
# customer_handling_score_10                         7.7
# overall_interview_score_10                         5.3
# document_verification                             Fail
# background_check_status                            NaN
# interview_result                               On Hold
# rejection_reason                                   NaN
# onboarding_date                                      -
# is_currently_active                              false
#
#                                                    1                      2   \
# driver_id                                   DRV032785              DRV011323
# driver_name                                Amit Gupta          Yogesh Nair
# age                                                45                     53
# city                                        Ahmedabad                Lucknow
# phone                                      9940345570             9170487337
# email                       amit.gupta@rediffmail.com                    NaN
# platform                                         Uber                   uber
# vehicle_type                                    Mini                     SUV
# vehicle_condition                           Excellent                    avg
# experience_level                              Fresher                 0-1 yr
# preferred_shift                                     -                    NaN
# reason_for_joining                                NaN          Not disclosed
# languages_known               Kannada, Tamil, Marathi  Tamil, Marathi, Hindi
# overall_driver_rating                             NaN                    5.8
# total_trips_completed                          5073.0                    NaN
# trip_completion_rate_%                           99.8                   75.8
# cancellation_rate_%                              28.5                   29.3
# avg_daily_earnings_INR                           1164                   2394
# total_complaints                                 18.0                   17.0
# total_compliments                                22.0                   59.0
# peak_hour_availability                              1                     No
# interview_date                              June 2021          February 2021
# communication_score_10                            7.0                    NaN
# driving_test_score_10                             9.3                    6.3
# route_knowledge_score_10                          NaN                    9.0
# customer_handling_score_10                        9.0                    5.5
# overall_interview_score_10                        8.1                    6.9
# document_verification                             NaN                    NaN
# background_check_status                         Clear                  clear
# interview_result                              On Hold               Selected
# rejection_reason                                  NaN                    NaN
# onboarding_date                                     -          19 April 2021
# is_currently_active                                No                  false
#
#                                                     3   \
# driver_id                                    DRV022168
# driver_name                                Manoj Patel
# age                                                 46
# city                                         Hyderabad
# phone                                       9246425981
# email                          manoj.patel@hotmail.com
# platform                                        RAPIDO
# vehicle_type                                      Mini
# vehicle_condition                                  NaN
# experience_level                               1-3 yrs
# preferred_shift                                    Day
# reason_for_joining                                 NaN
# languages_known             Gujarati, Kannada, Marathi
# overall_driver_rating                              4.8
# total_trips_completed                            262.0
# trip_completion_rate_%                            64.4
# cancellation_rate_%                               21.7
# avg_daily_earnings_INR                            1412
# total_complaints                                  24.0
# total_compliments                                  3.0
# peak_hour_availability                           false
# interview_date                              03-05-2021
# communication_score_10                             7.4
# driving_test_score_10                              8.7
# route_knowledge_score_10                           9.6
# customer_handling_score_10                         5.3
# overall_interview_score_10                         7.8
# document_verification                          unknown
# background_check_status                          Clear
# interview_result                              Selected
# rejection_reason                                   NaN
# onboarding_date                             2021/05/27
# is_currently_active                                  0
#
#                                                     4   \
# driver_id                                    DRV040782
# driver_name                           Vikram Chaudhary
# age                                                 25
# city                                           KOLKATA
# phone                                          9282240
# email                       vikram.chaudhary@gmail.com
# platform                                         Uber
# vehicle_type                                       suv
# vehicle_condition                                 GOOD
# experience_level                               Fresher
# preferred_shift                                      -
# reason_for_joining                         Side hustle
# languages_known                          Hindi, Telugu
# overall_driver_rating                              4.4
# total_trips_completed                           1910.0
# trip_completion_rate_%                            97.6
# cancellation_rate_%                               33.2
# avg_daily_earnings_INR                            1702
# total_complaints                                  16.0
# total_compliments                                  NaN
# peak_hour_availability                             yes
# interview_date                                     NaN
# communication_score_10                             4.0
# driving_test_score_10                             12.7
# route_knowledge_score_10                           6.5
# customer_handling_score_10                         7.9
# overall_interview_score_10                         6.0
# document_verification                             FAIL
# background_check_status                          clear
# interview_result                              Rejected
# rejection_reason                    Low rating history
# onboarding_date                                      -
# is_currently_active                                 NO
#
#                                                     5   \
# driver_id                                    DRV003740
# driver_name                           Sanjay Chaudhary
# age                                                -32
# city                                              Pune
# phone                                   +91-9120959146
# email                       sanjay.chaudhary@yahoo.com
# platform                                 Uber & Rapido
# vehicle_type                                      BIKE
# vehicle_condition                            excellent
# experience_level                               Fresher
# preferred_shift                                   Both
# reason_for_joining                                 NaN
# languages_known                         English, Tamil
# overall_driver_rating                              3.1
# total_trips_completed                           2354.0
# trip_completion_rate_%                            72.8
# cancellation_rate_%                                0.1
# avg_daily_earnings_INR                          1976/-
# total_complaints                                  14.0
# total_compliments                                  NaN
# peak_hour_availability                              NO
# interview_date                              March 2023
# communication_score_10                             8.1
# driving_test_score_10                              8.8
# route_knowledge_score_10                           8.6
# customer_handling_score_10                        10.5
# overall_interview_score_10                        -1.4
# document_verification                             FAIL
# background_check_status                            NaN
# interview_result                              Selected
# rejection_reason                                   NaN
# onboarding_date                             April 2023
# is_currently_active                                  N
#
#                                                     6   \
# driver_id                                    DRV037372
# driver_name                           Rakesh Chaudhary
# age                                                 21
# city                                           Lucknow
# phone                                   +91-9109648055
# email                       rakesh.chaudhary@gmail.com
# platform                                 Uber & Rapido
# vehicle_type                                      BIKE
# vehicle_condition                              Average
# experience_level                                0-1 yr
# preferred_shift                                   Both
# reason_for_joining                        Extra income
# languages_known                English, Tamil, Marathi
# overall_driver_rating                              4.3
# total_trips_completed                           6273.0
# trip_completion_rate_%                            84.6
# cancellation_rate_%                               33.4
# avg_daily_earnings_INR                            1339
# total_complaints                                  44.0
# total_compliments                                 19.0
# peak_hour_availability                            True
# interview_date                              25-06-2023
# communication_score_10                             NaN
# driving_test_score_10                              8.1
# route_knowledge_score_10                           8.7
# customer_handling_score_10                         9.7
# overall_interview_score_10                         8.2
# document_verification                              NaN
# background_check_status                        pending
# interview_result                              Selected
# rejection_reason                                   NaN
# onboarding_date                             08-08-2023
# is_currently_active                               true
#
#                                                    7   \
# driver_id                                   DRV042083
# driver_name                             Naveen Mishra
# age                                               999
# city                                            Delhi
# phone                                         9988246
# email                       naveen.mishra@hotmail.com
# platform                                        Uber
# vehicle_type                                      suv
# vehicle_condition                           Excellent
# experience_level                               0-1 yr
# preferred_shift                                   Day
# reason_for_joining                  Lost previous job
# languages_known                                 Hindi
# overall_driver_rating                             3.9
# total_trips_completed                             NaN
# trip_completion_rate_%                           94.8
# cancellation_rate_%                              11.4
# avg_daily_earnings_INR                           1443
# total_complaints                                 21.0
# total_compliments                                68.0
# peak_hour_availability                            YES
# interview_date                        24 January 2022
# communication_score_10                            4.1
# driving_test_score_10                             8.8
# route_knowledge_score_10                          6.4
# customer_handling_score_10                        NaN
# overall_interview_score_10                        6.0
# document_verification                             NaN
# background_check_status                         Clear
# interview_result                             Selected
# rejection_reason                                  NaN
# onboarding_date                            2022/02/06
# is_currently_active                                 0
#
#                                                   8   \
# driver_id                                  DRV030189
# driver_name                             Hitesh Singh
# age                                               43
# city                                         Kolkata
# phone                                     9994609866
# email                                            NaN
# platform                                        UBER
# vehicle_type                                    Mini
# vehicle_condition                          Excellent
# experience_level                              5+ yrs
# preferred_shift                                 Both
# reason_for_joining                   Family pressure
# languages_known             Tamil, Gujarati, Bengali
# overall_driver_rating                            4.8
# total_trips_completed                         3911.0
# trip_completion_rate_%                           NaN
# cancellation_rate_%                              2.3
# avg_daily_earnings_INR                          2430
# total_complaints                             99999.0
# total_compliments                                NaN
# peak_hour_availability                           yes
# interview_date                                   NaN
# communication_score_10                           7.3
# driving_test_score_10                           -1.1
# route_knowledge_score_10                         7.9
# customer_handling_score_10                      10.7
# overall_interview_score_10                       8.3
# document_verification                           FAIL
# background_check_status                          NaN
# interview_result                            Selected
# rejection_reason                                 NaN
# onboarding_date                 2022-06-08T00:00:00Z
# is_currently_active                                1
#
#                                                   9                       10  \
# driver_id                                  DRV029154               DRV017809
# driver_name                           Harish Chauhan             Anil Sharma
# age                                               39                      26
# city                                         Chennai                 Lucknow
# phone                                     9712392703              9699383157
# email                       harish.chauhan@gmail.com  anil.sharmahotmail.com
# platform                                        UBER                  Rapido
# vehicle_type                                    Bike                    BIKE
# vehicle_condition                               GOOD               excellent
# experience_level                              0-1 yr                 3-5 yrs
# preferred_shift                                 Both                   NIGHT
# reason_for_joining                              none           Full time job
# languages_known                              Marathi                 English
# overall_driver_rating                            3.3                     4.9
# total_trips_completed                         4925.0                  1890.0
# trip_completion_rate_%                          63.1                    90.8
# cancellation_rate_%                              3.4                    11.4
# avg_daily_earnings_INR                          2256                     780
# total_complaints                                23.0                     9.0
# total_compliments                               75.0                    23.0
# peak_hour_availability                          True                       Y
# interview_date                         31 March 2021            22 June 2023
# communication_score_10                           7.6                     7.4
# driving_test_score_10                           11.6                     NaN
# route_knowledge_score_10                         7.7                     3.6
# customer_handling_score_10                       5.9                     6.2
# overall_interview_score_10                       6.7                     5.8
# document_verification                           FAIL                    Fail
# background_check_status                      Flagged                 FLAGGED
# interview_result                             On Hold                Waitlist
# rejection_reason                                 NaN          Not applicable
# onboarding_date                                    -                     NaN
# is_currently_active                                N                     yes
#
#                                                  11  \
# driver_id                                 DRV006146
# driver_name                           yogesh sharma
# age                                              39
# city                                      Ahmedabad
# phone                                    9222401263
# email                       yogesh.sharma@yahoo.com
# platform                                       Uber
# vehicle_type                                   Auto
# vehicle_condition                              GOOD
# experience_level                             0-1 yr
# preferred_shift                               NIGHT
# reason_for_joining                    Not disclosed
# languages_known                   Marathi, Gujarati
# overall_driver_rating                           3.6
# total_trips_completed                        5196.0
# trip_completion_rate_%                         61.4
# cancellation_rate_%                            28.4
# avg_daily_earnings_INR                          NaN
# total_complaints                               35.0
# total_compliments                               1.0
# peak_hour_availability                            0
# interview_date                           07-02-2022
# communication_score_10                          7.5
# driving_test_score_10                           8.8
# route_knowledge_score_10                        5.2
# customer_handling_score_10                      NaN
# overall_interview_score_10                      7.7
# document_verification                           NaN
# background_check_status                     FLAGGED
# interview_result                            On Hold
# rejection_reason                                NaN
# onboarding_date                                 NaN
# is_currently_active                             YES
#
#                                                       12               13  \
# driver_id                                      DRV000742        DRV004608
# driver_name                                Naveen Mishra    Rajesh Sharma
# age                                                   37           30 yrs
# city                                              Mumbai             Pune
# phone                                         9470319661       9412359489
# email                       naveen.mishra@rediffmail.com              NaN
# platform                                         Unknown             uber
# vehicle_type                                       Sedan          unknown
# vehicle_condition                              Excellent        excellent
# experience_level                                 1-3 yrs           5+ yrs
# preferred_shift                                      Day             both
# reason_for_joining                           Side hustle  Family pressure
# languages_known                           Bengali, Tamil          Bengali
# overall_driver_rating                                4.6              4.9
# total_trips_completed                              455.0           6597.0
# trip_completion_rate_%                              71.0             77.0
# cancellation_rate_%                                 20.4             29.9
# avg_daily_earnings_INR                              1552              572
# total_complaints                                    30.0             48.0
# total_compliments                                   17.0             90.0
# peak_hour_availability                              True                N
# interview_date                                08-02-2021       08.11.2021
# communication_score_10                               5.5              NaN
# driving_test_score_10                                7.4              4.3
# route_knowledge_score_10                             6.8              8.5
# customer_handling_score_10                           4.9              6.7
# overall_interview_score_10                           NaN              NaN
# document_verification                               FAIL             Pass
# background_check_status                            Clear          pending
# interview_result                                Selected         Rejected
# rejection_reason                                     NaN              NaN
# onboarding_date                               2021/04/02                -
# is_currently_active                                    Y             true
#
#                                                    14              15  \
# driver_id                                   DRV004297       DRV037762
# driver_name                                Vikram Jha    MAHESH YADAV
# age                                                42              34
# city                                        AHMEDABAD          Mumbai
# phone                                  +91-9221346122      9461699795
# email                       vikram.jha@rediffmail.com             NaN
# platform                                        Uber              NaN
# vehicle_type                                      SUV             suv
# vehicle_condition                                Poor            poor
# experience_level                              Fresher          5+ yrs
# preferred_shift                                 Night             DAY
# reason_for_joining                               none  Flexible hours
# languages_known                              Gujarati           Tamil
# overall_driver_rating                             2.6             4.9
# total_trips_completed                          6929.0          4826.0
# trip_completion_rate_%                           78.6             NaN
# cancellation_rate_%                              30.4             3.1
# avg_daily_earnings_INR                           1121            2410
# total_complaints                                 31.0         99999.0
# total_compliments                                25.0            61.0
# peak_hour_availability                              N               1
# interview_date                             27-02-2021      2023/03/13
# communication_score_10                            4.1             9.7
# driving_test_score_10                             NaN            -0.6
# route_knowledge_score_10                          7.1             4.6
# customer_handling_score_10                        6.9             6.8
# overall_interview_score_10                        NaN             NaN
# document_verification                         Pending            Pass
# background_check_status                       Flagged         Pending
# interview_result                              On Hold        Selected
# rejection_reason                                  NaN              na
# onboarding_date                                   NaN      2023/04/02
# is_currently_active                              True             YES
#
#                                                    16  \
# driver_id                                   DRV014488
# driver_name                             Harish Shukla
# age                                                21
# city                                          Lucknow
# phone                                             NaN
# email                       harish.shukla@hotmail.com
# platform                                       Rapido
# vehicle_type                                     Mini
# vehicle_condition                                Good
# experience_level                                  NaN
# preferred_shift                                   NaN
# reason_for_joining                      Not disclosed
# languages_known                      Gujarati, Telugu
# overall_driver_rating                             3.2
# total_trips_completed                          1171.0
# trip_completion_rate_%                           90.8
# cancellation_rate_%                              13.5
# avg_daily_earnings_INR                        1890.00
# total_complaints                                  NaN
# total_compliments                                35.0
# peak_hour_availability                              1
# interview_date                                    NaN
# communication_score_10                            8.2
# driving_test_score_10                             6.3
# route_knowledge_score_10                          9.0
# customer_handling_score_10                        6.8
# overall_interview_score_10                        7.6
# document_verification                         Pending
# background_check_status                       FLAGGED
# interview_result                             Rejected
# rejection_reason                   Low rating history
# onboarding_date                                   NaN
# is_currently_active                                 Y
#
#                                                  17                      18  \
# driver_id                                 DRV006699               DRV047561
# driver_name                           Pradeep Patel            lokesh dubey
# age                                              25                      44
# city                                        Chennai               Bangalore
# phone                                    9414605629              9221003020
# email                       pradeep.patel@gmail.com  lokesh.dubey@yahoo.com
# platform                              Uber & Rapido                 Unknown
# vehicle_type                                   Bike                    Auto
# vehicle_condition                              good                     NaN
# experience_level                             5+ yrs                 Fresher
# preferred_shift                                both                    Both
# reason_for_joining                      Side hustle          Flexible hours
# languages_known              Tamil, Marathi, Telugu                 English
# overall_driver_rating                       unrated                     2.6
# total_trips_completed                        5778.0                  6800.0
# trip_completion_rate_%                         80.7                    86.3
# cancellation_rate_%                            11.3                     1.1
# avg_daily_earnings_INR                         1911                    2086
# total_complaints                               21.0                    35.0
# total_compliments                               7.0                 99999.0
# peak_hour_availability                            N                   false
# interview_date                           28-07-2021              07.02.2023
# communication_score_10                          3.8                     7.9
# driving_test_score_10                           NaN                     9.3
# route_knowledge_score_10                       -1.2                     5.0
# customer_handling_score_10                      8.5                     7.7
# overall_interview_score_10                      6.5                     7.5
# document_verification                           NaN                     NaN
# background_check_status                         NaN                      na
# interview_result                            On Hold                     NaN
# rejection_reason                                NaN                     NaN
# onboarding_date                                 NaN           February 2023
# is_currently_active                               N                      no
#
#                                                         19
# driver_id                                        DRV047630
# driver_name                                Pr@deep Ch@uh@n
# age                                                     47
# city                                                 Delhi
# phone                                                  NaN
# email                       pradeep.chauhan@rediffmail.com
# platform                                            RAPIDO
# vehicle_type                                          Bike
# vehicle_condition                                Excellent
# experience_level                                   Fresher
# preferred_shift                                       both
# reason_for_joining                                     NaN
# languages_known                  Gujarati, Marathi, Telugu
# overall_driver_rating                                  3.4
# total_trips_completed                                746.0
# trip_completion_rate_%                                 NaN
# cancellation_rate_%                                   24.9
# avg_daily_earnings_INR                                 930
# total_complaints                                      29.0
# total_compliments                                     91.0
# peak_hour_availability                                   N
# interview_date                                  12.05.2023
# communication_score_10                                 4.2
# driving_test_score_10                                  7.7
# route_knowledge_score_10                               3.2
# customer_handling_score_10                             5.3
# overall_interview_score_10                             NaN
# document_verification                                  NaN
# background_check_status                            Pending
# interview_result                                       NaN
# rejection_reason                                       NaN
# onboarding_date                                   05/24/23
# is_currently_active                                      0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   driver_id                   49005 non-null  str
#  1   driver_name                 50000 non-null  str
#  2   age                         47543 non-null  str
#  3   city                        50000 non-null  str
#  4   phone                       46089 non-null  str
#  5   email                       45395 non-null  str
#  6   platform                    47761 non-null  str
#  7   vehicle_type                47775 non-null  str
#  8   vehicle_condition           39468 non-null  str
#  9   experience_level            47776 non-null  str
#  10  preferred_shift             38773 non-null  str
#  11  reason_for_joining          38637 non-null  str
#  12  languages_known             47847 non-null  str
#  13  overall_driver_rating       46033 non-null  str
#  14  total_trips_completed       45930 non-null  float64
#  15  trip_completion_rate_%      45565 non-null  float64
#  16  cancellation_rate_%         45484 non-null  float64
#  17  avg_daily_earnings_INR      47489 non-null  str
#  18  total_complaints            45965 non-null  float64
#  19  total_compliments           46024 non-null  float64
#  20  peak_hour_availability      50000 non-null  str
#  21  interview_date              45067 non-null  str
#  22  communication_score_10      45416 non-null  float64
#  23  driving_test_score_10       45559 non-null  float64
#  24  route_knowledge_score_10    45448 non-null  float64
#  25  customer_handling_score_10  45500 non-null  float64
#  26  overall_interview_score_10  45545 non-null  float64
#  27  document_verification       36233 non-null  str
#  28  background_check_status     36549 non-null  str
#  29  interview_result            45243 non-null  str
#  30  rejection_reason            12174 non-null  str
#  31  onboarding_date             26172 non-null  str
#  32  is_currently_active         50000 non-null  str
# dtypes: float64(10), str(23)
# memory usage: 12.6 MB

# %%
print('The NaN % in the Data is: \n')
print((df.isna().sum()/df.shape[0])*100)
# Out:
# The NaN % in the Data is:
# driver_id                      1.990
# driver_name                    0.000
# age                            4.914
# city                           0.000
# phone                          7.822
# email                          9.210
# platform                       4.478
# vehicle_type                   4.450
# vehicle_condition             21.064
# experience_level               4.448
# preferred_shift               22.454
# reason_for_joining            22.726
# languages_known                4.306
# overall_driver_rating          7.934
# total_trips_completed          8.140
# trip_completion_rate_%         8.870
# cancellation_rate_%            9.032
# avg_daily_earnings_INR         5.022
# total_complaints               8.070
# total_compliments              7.952
# peak_hour_availability         0.000
# interview_date                 9.866
# communication_score_10         9.168
# driving_test_score_10          8.882
# route_knowledge_score_10       9.104
# customer_handling_score_10     9.000
# overall_interview_score_10     8.910
# document_verification         27.534
# background_check_status       26.902
# interview_result               9.514
# rejection_reason              75.652
# onboarding_date               47.656
# is_currently_active            0.000
# dtype: float64

# %%
# Use this to find the nearly duplicates data in the data like driver id cant be same but there is so we should look out for that
columns = df.columns.to_list()
print('Number of Duplicates in each Column: \n')
for col in columns:
    print(f"{col}: {df.duplicated(subset=col).sum()}")
# Out:
# Number of Duplicates in each Column:
#
# driver_id: 3746
# driver_name: 47023
# age: 49889
# city: 49960
# phone: 6687
# email: 42935
# platform: 49981
# vehicle_type: 49984
# vehicle_condition: 49985
# experience_level: 49989
# preferred_shift: 49986
# reason_for_joining: 49987
# languages_known: 49594
# overall_driver_rating: 49937
# total_trips_completed: 40073
# trip_completion_rate_%: 49548
# cancellation_rate_%: 49598
# avg_daily_earnings_INR: 41434
# total_complaints: 49947
# total_compliments: 49897
# peak_hour_availability: 49986
# interview_date: 42800
# communication_score_10: 49878
# driving_test_score_10: 49888
# route_knowledge_score_10: 49878
# customer_handling_score_10: 49878
# overall_interview_score_10: 49884
# document_verification: 49988
# background_check_status: 49988
# interview_result: 49987
# rejection_reason: 49987
# onboarding_date: 43483
# is_currently_active: 49986

# %%
print(f'The Duplicates the whole dataset is {df.duplicated().sum()}')
# Out:
# The Duplicates the whole dataset is 951

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ## *Create Copy*

# %%
df_copy = df.copy()
print('Copy Created Boss✅')
# Out:
# Copy Created Boss✅

# %% [markdown]
# ## *Cleaning*

# %%
# Name Column
replacments = {'@':'A','3':'E','0':'O'} 
for char, replacment in replacments.items():
    df_copy['driver_name'] = df_copy['driver_name'].replace(char,replacment,regex=True)
df_copy['driver_name'] = df_copy['driver_name'].str.strip().str.title()



# Age Column
replacments = {'yrs':'','unknown':np.nan} 
for char, replacment in replacments.items():
    df_copy['age'] = df_copy['age'].replace(char,replacment,regex=True)
df_copy['age'] = df_copy['age'].str.strip().astype('float')
df_copy.loc[df_copy['age']<18,'age'] = np.nan
df_copy.loc[df_copy['age']>50,'age'] = np.nan



# City Column
df_copy['city'] = df_copy['city'].str.strip().str.title()
replacments = {'Chenna':'Chennai','Bangalroe':'Bangalore','Dlhi':'Delhi','Mumabi':'Mumbai'}
for char,replacment in replacments.items():
    df_copy['city'] = df_copy['city'].replace(char,replacment)
    
    
    
# Phone No. Column
df_copy['phone'] = df_copy['phone'].str.replace(r'\+91|-|\s', '', regex=True)
df_copy.loc[(df_copy['phone'].str.len() != 10),'phone'] = 'Unknown'




# Email Column
df_copy['email'] = df_copy['email'].replace('@@','@',regex=True)
df_copy['email'] = df_copy['email'].fillna('Unknown')




# Platform,Vehical Type & Condition, shift, Experience Column
columns = ['vehicle_type',
           'platform',
           'vehicle_condition',
           'experience_level',
           'preferred_shift',
           'reason_for_joining',
           'document_verification',
           'background_check_status',
           'interview_result',
           'rejection_reason']
for col in columns:
    df_copy[col] = df_copy[col].str.strip().str.title()
    replacments = {'None':'Unknown','-':'Unknown','Na':'Unknown','Avg':'Average'}
    df_copy[col] = df_copy[col].replace(replacments)
    df_copy[col] = df_copy[col].fillna('Unknown')
    
    
    

# Language Column
df_copy['languages_known'] = df_copy['languages_known'].str.split(',')



# Rating Column
df_copy['overall_driver_rating'] = df_copy['overall_driver_rating'].replace('unrated',np.nan).astype('float')
df_copy.loc[df_copy['overall_driver_rating']<0,'overall_driver_rating'] = np.nan
df_copy.loc[df_copy['overall_driver_rating']>10,'overall_driver_rating'] = np.nan
df_copy['overall_driver_rating'] = df_copy['overall_driver_rating'].fillna(-1) # -1 = Unrated



# Trip Column
df_copy.loc[df_copy['total_trips_completed']<0,'total_trips_completed'] = np.nan
df_copy['total_trips_completed'] = df_copy['total_trips_completed'].fillna(round(df_copy['total_trips_completed'].median(),0))



# Cancellation Rate
df_copy.loc[df_copy['cancellation_rate_%']<0,'cancellation_rate_%'] = np.nan
df_copy.loc[df_copy['cancellation_rate_%']>100,'cancellation_rate_%'] = np.nan
df_copy['cancellation_rate_%'] = df_copy['cancellation_rate_%'].fillna(round(df_copy['cancellation_rate_%'].mean(),1))




# Salary Column
df_copy['avg_daily_earnings_INR'] = df_copy['avg_daily_earnings_INR'].replace(['₹','Rs.','/-'],'',regex=True).astype('float')
df_copy.loc[df_copy['avg_daily_earnings_INR']<0,'avg_daily_earnings_INR'] = np.nan
df_copy.loc[df_copy['avg_daily_earnings_INR']>10000,'avg_daily_earnings_INR'] = np.nan
df_copy['avg_daily_earnings_INR'] = df_copy['avg_daily_earnings_INR'].fillna(round(df_copy['avg_daily_earnings_INR'].mean(),1))




# Complaint, Compliments column
columns = ['total_compliments','total_complaints']
for col in columns:
    df_copy.loc[df_copy[col]<0,col] = np.nan
    df_copy.loc[df_copy[col]>50,col] = np.nan
    df_copy[col] = df_copy[col].fillna(round(df_copy[col].median(),0))
    
    
    
    
# Availablity Column
column = ['peak_hour_availability','is_currently_active']
for items in column:
    df_copy[items] = df_copy[items].str.strip().str.title().replace(['False','Na','0','N'],'No')
    df_copy[items] = df_copy[items].str.strip().str.title().replace(['1','True','Y'],'Yes')
    df_copy[items] = df_copy[items].str.strip().str.title().replace(['-','None'],'Unknown')
    df_copy[items] = df_copy[items].fillna('Unknown')
    
    
    

# Date Column
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    columns = ['interview_date','onboarding_date']
    for col in columns:
        df_copy[col] = pd.to_datetime(
            df_copy[col],
            errors='coerce',
            dayfirst=True,
            utc=True
        )
        df_copy[col] = df_copy[col].fillna(df_copy[col].median())





# Communication Score
columns = ['driving_test_score_10',
           'communication_score_10',
           'route_knowledge_score_10',
           'customer_handling_score_10',
           'overall_interview_score_10']
for col in columns:
    df_copy.loc[df_copy[col]<0,col] = np.nan
    df_copy.loc[df_copy[col]>10,col] = np.nan
    df_copy[col] = df_copy[col].fillna(round(df_copy[col].mean(),1))
